# %% [markdown]
# <a href="https://colab.research.google.com/github/petermr/CEVOpen/blob/master/fun_with_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pandas DataFrame Quick Tutorial
# This Colab introduces DataFrames, which are the central data structure in the pandas API. This Colab is semi comprehensive DataFrames tutorial.
#
# A DataFrame is similar to an in-memory spreadsheet. Like a spreadsheet:
#
# A DataFrame stores data in cells.
# A DataFrame has named columns (usually) and numbered rows.

# %% [markdown]
# #Installing and Loading pandas

# %%
# to install the panda packages in your enviorment do
# !pip install pandas
#then import pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %% [markdown]
# # Reading and Saving csv files

# %%
#to read any csv file do
df = pd.read_csv('/content/Terpene and Other Plant Pathway Figures.csv')
df
# Out:
#         pmcid  ...                            figure.title
# 0  PMC6323817  ...  Differentially expressed genes (DEG...
# 1  PMC6348685  ...  Putative genes and their expression...
# 2  PMC6356271  ...              Terminal telomeric complex
# 3  PMC6360084  ...  Identification, expression, and phy...
# 4  PMC6374618  ...  Schematic relationships between the...
# 5  PMC6394206  ...  Proposed diterpene pathway based on...
# 6  PMC6412517  ...  Induction of secondary metabolism i...
# 7  PMC6423058  ...            Pathway of terpene synthesis
# 8  PMC6437448  ...  Biosynthetic pathway engineering fo...
# 9  PMC6441073  ...  DEGs involved in the plant–pathogen...
#
# [10 rows x 6 columns]

# %%
#to save csv file
df.to_csv('new_csv')

# %% [markdown]
# #data visualization

# %%
df.head(10) # return top 10 values of the dataframe
# Out:
#         pmcid  ...                            figure.title
# 0  PMC6323817  ...  Differentially expressed genes (DEG...
# 1  PMC6348685  ...  Putative genes and their expression...
# 2  PMC6356271  ...              Terminal telomeric complex
# 3  PMC6360084  ...  Identification, expression, and phy...
# 4  PMC6374618  ...  Schematic relationships between the...
# 5  PMC6394206  ...  Proposed diterpene pathway based on...
# 6  PMC6412517  ...  Induction of secondary metabolism i...
# 7  PMC6423058  ...            Pathway of terpene synthesis
# 8  PMC6437448  ...  Biosynthetic pathway engineering fo...
# 9  PMC6441073  ...  DEGs involved in the plant–pathogen...
#
# [10 rows x 6 columns]

# %%
df.tail(10) # return bottom 10 values of the dataframe
# Out:
#         pmcid  ...                            figure.title
# 0  PMC6323817  ...  Differentially expressed genes (DEG...
# 1  PMC6348685  ...  Putative genes and their expression...
# 2  PMC6356271  ...              Terminal telomeric complex
# 3  PMC6360084  ...  Identification, expression, and phy...
# 4  PMC6374618  ...  Schematic relationships between the...
# 5  PMC6394206  ...  Proposed diterpene pathway based on...
# 6  PMC6412517  ...  Induction of secondary metabolism i...
# 7  PMC6423058  ...            Pathway of terpene synthesis
# 8  PMC6437448  ...  Biosynthetic pathway engineering fo...
# 9  PMC6441073  ...  DEGs involved in the plant–pathogen...
#
# [10 rows x 6 columns]

# %%
df.columns # returns list of column names
# Out:
# Index(['pmcid', 'paper.title', 'authors', 'year', 'number', 'figure.title'], dtype='object')

# %%
df.index   # return indexes
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df.shape # return a tuple giving information aout the shape of the file for ex: (30,10) means the csv has 30 rows and 10 columns
print('NO of rows in the csv file are :{} and no of columns are: {}'.format(df.shape[0],df.shape[1]))
# Out:
# NO of rows in the csv file are :10 and no of columns are: 6

# %% [markdown]
# # statistical inference

# %%
df.max() # return max for each column
#df.min() # return min for each column
# Out:
# pmcid                                                  PMC6441073
# paper.title     Why Algae Release Volatile Organic Compounds—T...
# authors                                             Zhaojiang Zuo
# year                                                         2019
# number                                                   Figure 8
# figure.title                           Terminal telomeric complex
# dtype: object

# %%
df.mean() #return mean for each column
# Out:
# year    2019.0
# dtype: float64

# %%
df.var() #return variance for each column
# Out:
# year    0.0
# dtype: float64

# %%
df.std() #return standard deviation for each column
# Out:
# year    0.0
# dtype: float64

# %%
#if you want to find statistics of a column, lets say our dataframe has a column named 'weight' which signify the weight of each person:
df['longitude'].mean() # computes mean
df['longitude'].max() # return max
df['longitude'].min() # return min
df['longitude'].var() # return variance
df['longitude'].std() # return standard deviation

# %% [markdown]
# # combining two csv

# %%
#appending two csv files :

df1 = pd.read_csv('/content/Terpene and Other Plant Pathway Figures.csv')
df2 = pd.read_csv('/content/Terpene and Other Plant Pathway Figures (3).csv')
df_new = pd.concat([df1,df2], axis = 0).reset_index() ##horizontly
#df_new = pd.concat([df1,df2], axis = 1) ##vertically

# %%
df_new
# Out:
#     index       pmcid  ...     number                            figure.title
# 0       0  PMC6323817  ...     Fig. 6  Differentially expressed genes (DEG...
# 1       1  PMC6348685  ...     Fig. 4  Putative genes and their expression...
# 2       2  PMC6356271  ...   Figure 2              Terminal telomeric complex
# 3       3  PMC6360084  ...   Figure 8  Identification, expression, and phy...
# 4       4  PMC6374618  ...   FIGURE 4  Schematic relationships between the...
# 5       5  PMC6394206  ...  Figure 5:  Proposed diterpene pathway based on...
# 6       6  PMC6412517  ...   Figure 2  Induction of secondary metabolism i...
# 7       7  PMC6423058  ...   FIGURE 2            Pathway of terpene synthesis
# 8       8  PMC6437448  ...     Fig. 1  Biosynthetic pathway engineering fo...
# 9       9  PMC6441073  ...   Figure 3  DEGs involved in the plant–pathogen...
# 10      0  PMC6453882  ...   Figure 4  Overview of the proposed biosynthet...
# 11      1  PMC6475556  ...   Figure 7  The mechanisms of total triterpenes...
# 12      2  PMC6486373  ...   Fig. (1)  Possible mechanisms of the anti-tum...
# 13      3  PMC6509841  ...     Fig. 8  DEGs relevant to the “plant hormone...
# 14      4  PMC6544981  ...     Fig. 1  Co-production of farnesol and coenz...
# 15      5  PMC6546118  ...   FIGURE 3            Plant MAPK signaling pathway
# 16      6  PMC6585571  ...   FIGURE 1  Schematic Carotenoid Metabolic Path...
# 17      7  PMC6589721  ...   Figure 2  Multifaceted roles of BC1 in the sc...
# 18      8  PMC6589721  ...   Figure 3  Hypothetical working model illustra...
# 19      9  PMC6589726  ...   Figure 1  Scheme of sesquiterpenoid phytoalex...
#
# [20 rows x 7 columns]

# %% [markdown]
# #data cleaning

# %%
#Now the data mostly we get from the internet or other source are not clean, which means several for the inputs might be empty, or junk
#In order to clean the data some of the basic steps are:

pd.isna(df) #returns a boolean mask where values are nan.
# Out:
#    pmcid  paper.title  authors   year  number  figure.title
# 0  False        False    False  False   False         False
# 1  False        False    False  False   False         False
# 2  False        False    False  False   False         False
# 3  False        False    False  False   False         False
# 4  False        False    False  False   False         False
# 5  False        False    False  False   False         False
# 6  False        False    False  False   False         False
# 7  False        False    False  False   False         False
# 8  False        False    False  False   False         False
# 9  False        False    False  False   False         False

# %%
new_df = df.dropna()#remove the rows if any cell in them is empty
new_df
# Out:
#         pmcid  ...                            figure.title
# 0  PMC6323817  ...  Differentially expressed genes (DEG...
# 1  PMC6348685  ...  Putative genes and their expression...
# 2  PMC6356271  ...              Terminal telomeric complex
# 3  PMC6360084  ...  Identification, expression, and phy...
# 4  PMC6374618  ...  Schematic relationships between the...
# 5  PMC6394206  ...  Proposed diterpene pathway based on...
# 6  PMC6412517  ...  Induction of secondary metabolism i...
# 7  PMC6423058  ...            Pathway of terpene synthesis
# 8  PMC6437448  ...  Biosynthetic pathway engineering fo...
# 9  PMC6441073  ...  DEGs involved in the plant–pathogen...
#
# [10 rows x 6 columns]

# %%
df_filled = df.fillna(value=5) # filling the missing value with cetain vale here it is int
df_filled
# Out:
#         pmcid  ...                            figure.title
# 0  PMC6323817  ...  Differentially expressed genes (DEG...
# 1  PMC6348685  ...  Putative genes and their expression...
# 2  PMC6356271  ...              Terminal telomeric complex
# 3  PMC6360084  ...  Identification, expression, and phy...
# 4  PMC6374618  ...  Schematic relationships between the...
# 5  PMC6394206  ...  Proposed diterpene pathway based on...
# 6  PMC6412517  ...  Induction of secondary metabolism i...
# 7  PMC6423058  ...            Pathway of terpene synthesis
# 8  PMC6437448  ...  Biosynthetic pathway engineering fo...
# 9  PMC6441073  ...  DEGs involved in the plant–pathogen...
#
# [10 rows x 6 columns]

# %%
#df.duplicates() # return the no of duplicates present in the csv
df_no_duplicate= df.drop_duplicates(inplace = True) # remove duplicate elemments
df_no_duplicate

# %% [markdown]
# it return None which means there are no duplicates in the csv

# %%
#if you want to update value in any cell follow the comment below:
df.loc[7, 'longitude'] = 45 # here we are changing the value of
