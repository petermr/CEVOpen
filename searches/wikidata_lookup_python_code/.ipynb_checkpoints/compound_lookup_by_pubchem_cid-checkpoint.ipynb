# %%
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
import time
endpoint_url = "https://query.wikidata.org/sparql"
def get_results(endpoint_url, query):
    sparql = SPARQLWrapper(endpoint_url)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %%
comp = pd.read_table("../oil1000/__tables/compound_multisetCopy.tsv")

# %%
comp_filt = comp[(comp["WIKIDATA_id"] == "not found")]

comp_filt = comp_filt[comp_filt["PubChem_CID"] != "not found"]

# %%
for index, row in comp_filt.iterrows():
    print("PubChem_CID = " + row["PubChem_CID"])
    pubchem_cid = row["PubChem_CID"]
    sparql_query = '''
    SELECT ?item ?itemLabel 
    WHERE 
    {
      # ?item wdt:P662 "''' + pubchem_cid + '''".
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
    }
       
    '''
    
    query_failed = False
    
    try:
        results = get_results(endpoint_url, sparql_query)
    except:
        try:
            time.sleep(0.5)
            results = get_results(endpoint_url, sparql_query)
        except:
            try:
                results = get_results(endpoint_url, sparql_query)
            except:
                try:
                    results = get_results(endpoint_url, sparql_query)
                except:
                    query_failed = True
                
            
    if len(results["results"]["bindings"]) > 0 :
    
        wikidata_id = results["results"]["bindings"][0]['item']['value'].split("/")[4]
        wikidata_label = results["results"]["bindings"][0]['itemLabel']['value']
        if wikidata_label == wikidata_id:
            wikidata_label = "No label defined "
        print("Found: " + wikidata_label)
        
        
    else:
        print('Not found')

    
    time.sleep(0.5)
# Out:
# PubChem_CID = 1549992
# Not found
# PubChem_CID = 100949538
# Not found
# PubChem_CID = 11770062
# Not found
# PubChem_CID = 15560330
# Found: No label defined
# PubChem_CID = 13918681
# Found: (Z)-p-menth-2-en-1-ol
# PubChem_CID = 91753433
# Not found
# PubChem_CID = 524198
# Not found
# PubChem_CID = 6429077
# Found: No label defined
# PubChem_CID = 10798255
# Not found
# PubChem_CID = 519960
# Not found
# PubChem_CID = 6432454
# Not found
# PubChem_CID = 6986
# Found: p-menthan-3-one
# PubChem_CID = 636822
# Found: α-asarone
# PubChem_CID = 110898
# Not found
# PubChem_CID = 60147454
# Not found
# PubChem_CID = 25244198
# Not found
# PubChem_CID = 111274
# Found: (1R,4R)-1-methyl-4-prop-1-en-2-ylcyclohex-2-en-1-ol
# PubChem_CID = 6429080
# Not found
# PubChem_CID = 14619932
# Not found
# PubChem_CID = 530426
# Not found
# PubChem_CID = 536595
# Not found
# PubChem_CID = 6429357
# Not found
# PubChem_CID = 5284507
# Not found
# PubChem_CID = 12618691
# Not found
# PubChem_CID = 6428444
# Not found
# PubChem_CID = 9859337
# Not found
# PubChem_CID = 5365879
# Not found
# PubChem_CID = 5281758
# Found: β-asarone
# PubChem_CID = 30875
# Not found
# PubChem_CID = 535346
# Not found
# PubChem_CID = 4276
# Found: myristicin
# PubChem_CID = 527113
# Not found
# PubChem_CID = 5498519
# Not found
# PubChem_CID = 21674978
# Not found
# PubChem_CID = 21675005
# Not found
# PubChem_CID = 10585158
# Not found
# PubChem_CID = 90351
# Not found
# PubChem_CID = 11972555
# Not found
# PubChem_CID = 519323
# Not found
# PubChem_CID = 5365883
# Not found
# PubChem_CID = 100197
# Not found
# PubChem_CID = 998
# Found: phenylacetaldehyde
# PubChem_CID = 7707
# Found: 3-phenylpropionaldehyde
# PubChem_CID = 522161
# Not found
# PubChem_CID = 13901618
# Not found
# PubChem_CID = 162747
# Not found
# PubChem_CID = 12612679
# Not found
# PubChem_CID = 102024
# Found: (1R,5R)-carvyl acetate
# PubChem_CID = 1549107
# Not found
# PubChem_CID = 6429040
# Not found
# PubChem_CID = 97829
# Found: (Z)-thujopsene
# PubChem_CID = 177099
# Found: latifolone
# PubChem_CID = 523035
# Found: dehydrocineole
# PubChem_CID = 21595261
# Not found
# PubChem_CID = 11463
# Found: terpinolene
# PubChem_CID = 11858788
# Not found
# PubChem_CID = 6973643
# Found: beta-fenchol
# PubChem_CID = 12313019
# Found: No label defined
# PubChem_CID = 91730038
# Not found
# PubChem_CID = 14830706
# Not found
# PubChem_CID = 13304977
# Not found
# PubChem_CID = 520687
# Not found
# PubChem_CID = 91746535
# Not found
# PubChem_CID = 325
# Found: 4-isopropylbenzyl alcohol
# PubChem_CID = 556963
# Not found
# PubChem_CID = 15491228
# Not found
# PubChem_CID = 9862
# Found: 6-methyl-5-hepten-2-one
# PubChem_CID = 530411
# Not found
# PubChem_CID = 6428421
# Not found
# PubChem_CID = 5368743
# Not found
# PubChem_CID = 6951358
# Found: (1R,5S)-carvyl acetate
# PubChem_CID = 162747
# Not found
# PubChem_CID = 6428434
# Not found
# PubChem_CID = 6431130
# Not found

# %%
# Out:
# Q67880197
# (Z)-p-menth-2-en-1-ol
