# %%
import gensim as gm 
import pandas as pd
import numpy as np 
import os
import glob as glob
import pathlib
import xml.etree.ElementTree as ET
import nltk 
from rake_nltk import Rake
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
ra = Rake()
import re

# %%
mydir = 'C:\\Users\\91981\\CEVOpen\\searches\\oil186\\PMC*'
files = glob.glob("C:\\Users\\91981\\CEVOpen\\searches\\oil186\\PMC*\\sections\\1_body\\*\\*.txt", recursive= True)
for file in files:
    print(file)
# Out:
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\0_introduction\0_title.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\0_introduction\1_p.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\0_introduction\2_p.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\0_introduction\3_p.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\1_materials_and_methods\1_p.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\1_materials_and_methods\2_p.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\1_materials_and_methods\3_p.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\1_materials_and_methods\4_p.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\1_materials_and_methods\5_p.txt
# C:\Users\91981\CEVOpen\searches\oil186\PMC4391421\sections\1_body\1_materials_and_methods\6_p.txt
# ...

# %%
len(files)
# Out:
# 1041

# %%
with open("results.txt", "wb") as outfile:
    for file in files:
        with open(file, "rb") as infile:
            outfile.write(infile.read())

# %%
file1 = open("results.txt", "r")
text_result = file1.read()
text_result= re.sub(r"[-()\"#/@;:<>{}`+=~|.!?,]", "", text_result)
NLTK_stop_words_list=stopwords.words('english')
custom_stop_word_list=['figure','permission','reproduced','copyright', 'authors', 'society',"university",'table',
"manuscript", "published", "declare", "conflict", "research", "diagram", "images", "version",
"data", "Fig", "different", "time", "min", "experiments", "group", "analysis",
"study", "activity", "treated", "Extraction", "using", "mean", "work", "file",
"samples", "performed", "analyzed", "support", "values", "approved", "significant",
"thank", "interest", "supported",'is','et','al']
final_stopword_list= custom_stop_word_list + NLTK_stop_words_list
tokens = word_tokenize(text_result) 
sentence_without_stopword = [k for k in tokens if not k in final_stopword_list] 
print(tokens) 
print(sentence_without_stopword)
print(text_result)
# Out:
# ['0', 'Introduction', '0', 'The', 'genus', 'Thymus', 'member', 'of', 'the', 'Lamiaceae', 'family', 'contains', 'about', '400', 'species', 'of', 'perennial', 'aromatic', 'evergreen', 'or', 'semievergreen', 'herbaceous', 'plants', 'with', 'many', 'subspecies', 'varieties', 'subvarieties', 'and', 'forms', '[', '1', ']', '1', 'In', 'Romania', 'the', 'Thymus', 'genus', 'contains', 'one', 'species', 'cultivated', 'as', 'aromatic', 'plant', 'Thymus', 'vulgaris', 'and', 'other', '18', 'wild', 'species', '[', '2', ']', '2', 'T', 'vulgaris', 'thyme', 'locally', 'known', 'as', 'cimbru', 'is', 'widely', 'used', 'in', 'the', 'Romanian', 'folk', 'medicine', 'for', 'its', 'expectorant', 'antitussive', 'antibroncholitic', 'antispasmodic', 'anthelmintic', 'carminative', 'and', 'diuretic', 'properties', '0', 'Various', 'studies', 'have', 'aimed', 'to', 'investigate', 'the', 'chemical', 'composition', 'and', 'biological', 'properties', 'of', 'the', 'T', 'vulgaris', 'essential', 'oil', 'EO', '1', 'Accor
# ...

# %%
keyword_txt= ra.extract_keywords_from_text(text_result)

# %%
print(keyword_txt)
# Out:
# None

# %%
b=ra.get_ranked_phrases()[0:100]

# %%
print(b)
# Out:
# ['zaki 2009 koheil et al 2011 dehshahri et al 2012 lalas et al 2012 alowaisi et al 2014 moustafa et al 2014 majali et al 2015 safaeian et al 2015 ullah et al 2015 alrayes et al 2016 elawady et al 2016 azim et al 2017 elabd et al 2017 saleh et al 2017 3', 'bioactive constituents viz 2allyl5ethoxy4methoxyphenol 4terpineol lysidine epieudesmin spathulenol furylethyl ketone borneol nonanoic acid 2255tetramethyl3hexanol galgravin bornyl acetate retusin 9 e12 e15 e91215octadecatrien1ol geranylacetate butyl butanoate sakuranin camphor acetic acid isoelemicin acetaphenone ursolic acid dehydroabietic acid methyl ether isoeugenol apigenin 47dimethylether linalool dehydrodiisoeugenol elemicin', 'technology mashhad iran spectrophotometer biochrom cambridge uk kjeldahl auto analyser 130 tecator co warrington uk scanning electron microscopy sem s360 oxford england refractometer abbe kobe jepan gas chromatographymass spectrometry agilent san francisco usa rancimat metrohm herisau swiss', 'precursor
# ...

# %%
type(text_result)
# Out:
# str
